# %%
import pandas as  pd

# %%
df=pd.read_csv("delhimetrorail.csv")

# %%
df
# Out:
#                                                item_name  \
# 0                                                  CHAIN
# 1                                           EARBUDS CASE
# 2                                              CARRY BAG
# 3                                                    BAG
# 4                                                 JACKET
# ...                                                  ...
# 13708                                             frocks
# 13709                                        jeans towel
# 13710                                            blanket
# 13711                       bag with bedsheet cap jacket
# 13712  BAG HAVING CASH, LUNCH, BOTTLE, BANK DOCUMENTS...
#
#                                              description item_quantity  \
# 0                                            METAL CHAIN             1
# 1                                          BLACK EARBUDS             1
# 2                                     OLD LADIES CLOTHES             1
# 3                    UTENSILS , PEN , HANGER & LUNCH BOX             1
# 4                                            GREY JACKET             2
# ...                                                  ...           ...
# 13708                                             frocks             1
# 13709                                        jeans towel             1
# 13710                                            blanket             1
# 13711                       bag with bedsheet cap jacket             1
# 13712  BAG HAVING CASH, LUNCH, BOTTLE, BANK DOCUMENTS...             1
#
#                           station_name receiving_date receiving_time
# 0                             VAISHALI     21/03/2024       11:35:00
# 1                  BRIG. HOSHIAR SINGH     20/03/2024       12:15:00
# 2                              RITHALA     20/03/2024       10:00:00
# 3                           KAROL BAGH     20/03/2024       09:30:00
# 4      YASHOBHOOMI DWARKA SECTOR  - 25     20/03/2024       11:00:00
# ...                                ...            ...            ...
# 13708                      JLN STADIUM     11/01/2022       19:50:00
# 13709                   SAROJINI NAGAR     11/01/2022       20:40:00
# 13710                        KAUSHAMBI     11/01/2022       17:30:00
# 13711                   SAMAYPUR BADLI     11/01/2022       17:10:00
# 13712   RAJA NAHAR SINGH (BALLABHGARH)     15/12/2021       20:05:00
#
# [13713 rows x 6 columns]

# %%
df.head(30)
# Out:
#        item_name                                        description  \
# 0          CHAIN                                        METAL CHAIN
# 1   EARBUDS CASE                                      BLACK EARBUDS
# 2      CARRY BAG                                 OLD LADIES CLOTHES
# 3            BAG                UTENSILS , PEN , HANGER & LUNCH BOX
# 4         JACKET                                        GREY JACKET
# 5            BAG  WITH DENIM PANT & JACKET ,TIFFIN ,TOWEL ,LOWER...
# 6       JUTE BAG                                     WITH LUNCH BOX
# 7    BROWN PURSE  BANK CARDS , AADHAR CARD , PAN CARD OF MR. NAR...
# 8       JUTE BAG                           WITH BOTTLE ,GLASS BOXES
# 9          WATCH                                         LADY WATCH
# 10       EARBUDS                                      BLACK EARBUDS
# 11         PURSE                 WITH DL BANK CARDS OF SANJAY YADAV
# 12           BAG                  WITH CLOTHS ORNAMENTS  HAIR DRYER
# 13        WALLET              AADHAR CARD & CASH OF MS. MAHIMA JAIN
# 14     CARRY BAG  BLANKET , SWEATER & MEDICAL DOCUMENTS OF MR. S...
# 15     LUNCH BAG                                  LUNCH BOX & SPOON
# 16      PASSPORT                   OF RUSSIAN LADY TATYANA BAKULINA
# 17       EARBUDS                                      BLACK EARBUDS
# 18          RACK                              DVR & NETWORKING RACK
# 19        HELMET                                       BLACK HELMET
# 20         PURSE                        WITH METRO CARD ,CASH,PHOTO
# 21         WATCH                                       LADIES WATCH
# 22      GREY BAG                     WITH CLOTHS ,SLIPPERS,EARRINGS
# 23      POLY BAG                            WITH LADIES  INNER WEAR
# 24        MOBILE                                     ONEPLUS MOBILE
# 25         PAYAL                                 SILVER COLOR PAYAL
# 26        MOBILE                                             MOBILE
# 27   TROLLEY BAG                        RED TROLLEY BAG WITH CLOTHS
# 28      POLY BAG                                   WITH OLD BLANKET
# 29      POLY BAG                                WITH HELMET,DUPATTA
#
#    item_quantity                       station_name receiving_date  \
# 0              1                           VAISHALI     21/03/2024
# 1              1                BRIG. HOSHIAR SINGH     20/03/2024
# 2              1                            RITHALA     20/03/2024
# 3              1                         KAROL BAGH     20/03/2024
# 4              2    YASHOBHOOMI DWARKA SECTOR  - 25     20/03/2024
# 5              2    YASHOBHOOMI DWARKA SECTOR  - 25     20/03/2024
# 6              1                     SAMAYPUR BADLI     20/03/2024
# 7              1                      KASHMERE GATE     20/03/2024
# 8              1                        IFFCO CHOWK     20/03/2024
# 9              1                       DELHI CANTT.     20/03/2024
# 10             1                   BOTANICAL GARDEN     20/03/2024
# 11             1                   BOTANICAL GARDEN     20/03/2024
# 12             1                        RAJIV CHOWK     20/03/2024
# 13             1  NEW DELHI (Yellow & Airport Line)     19/03/2024
# 14             1                     SAMAYPUR BADLI     19/03/2024
# 15             1                     SAMAYPUR BADLI     19/03/2024
# 16             1                        MANDI HOUSE     19/03/2024
# 17             1                            JHILMIL     19/03/2024
# 18             1                            JHILMIL     19/03/2024
# 19             1                      KASHMERE GATE     19/03/2024
# 20             1                          MOOLCHAND     19/03/2024
# 21             1                       CHIRAG DELHI     19/03/2024
# 22             1    YASHOBHOOMI DWARKA SECTOR  - 25     19/03/2024
# 23             1            RAMAKRISHNA ASHRAM MARG     19/03/2024
# 24             1                       LAJPAT NAGAR     19/03/2024
# 25             1                              AIIMS     18/03/2024
# 26             1                     DELHI AEROCITY     18/03/2024
# 27             1  NEW DELHI (Yellow & Airport Line)     18/03/2024
# 28             1                 DWARKA SECTOR - 21     18/03/2024
# 29             1                            RITHALA     18/03/2024
#
#    receiving_time
# 0        11:35:00
# 1        12:15:00
# 2        10:00:00
# 3        09:30:00
# 4        11:00:00
# 5        11:30:00
# 6        10:20:00
# 7        17:30:00
# 8        20:00:00
# 9        10:00:00
# 10       08:50:00
# 11       23:50:00
# 12       16:30:00
# 13       20:50:00
# 14       13:20:00
# 15       14:08:00
# 16       08:00:00
# 17       20:30:00
# 18       20:30:00
# 19       09:40:00
# 20       19:20:00
# 21       11:40:00
# 22       13:00:00
# 23       21:40:00
# 24       19:50:00
# 25       13:20:00
# 26       02:30:00
# 27       18:35:00
# 28       18:00:00
# 29       18:30:00

# %%
df.shape
# Out:
# (13713, 6)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13713, step=1)

# %%
df.columns
# Out:
# Index(['item_name', 'description', 'item_quantity', 'station_name',
#        'receiving_date', 'receiving_time'],
#       dtype='object')

# %%
df.dtypes
# Out:
# item_name         object
# description       object
# item_quantity     object
# station_name      object
# receiving_date    object
# receiving_time    object
# dtype: object

# %%
df["item_quantity"].unique()
# Out:
# array(['1', '2', '3', '4', nan, '06', '20', '5', '2030', '6', '11',
#        '1310', '02', '8', '04', '1350', '14:05', '7', '01', '07', '21:30'],
#       dtype=object)

# %%
df.nunique()
# Out:
# item_name         2977
# description       4271
# item_quantity       20
# station_name       229
# receiving_date     798
# receiving_time     743
# dtype: int64

# %%
df.count()
# Out:
# item_name         13713
# description        5505
# item_quantity      3202
# station_name      13713
# receiving_date    13713
# receiving_time    13713
# dtype: int64

# %%
df["item_name"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                                    CHAIN
# 1                                             EARBUDS CASE
# 2                                                CARRY BAG
# 3                                                      BAG
# 4                                                   JACKET
#                                ...
# 13708                                               frocks
# 13709                                          jeans towel
# 13710                                              blanket
# 13711                         bag with bedsheet cap jacket
# 13712    BAG HAVING CASH, LUNCH, BOTTLE, BANK DOCUMENTS...
# Name: item_name, Length: 13713, dtype: object>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13713 entries, 0 to 13712
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   item_name       13713 non-null  object
#  1   description     5505 non-null   object
#  2   item_quantity   3202 non-null   object
#  3   station_name    13713 non-null  object
#  4   receiving_date  13713 non-null  object
#  5   receiving_time  13713 non-null  object
# dtypes: object(6)
# memory usage: 642.9+ KB

# %%
df["receiving_date"][df['item_name']=='POLY BAG']
# Out:
# 23       19/03/2024
# 28       18/03/2024
# 29       18/03/2024
# 50       17/03/2024
# 56       16/03/2024
#             ...
# 13074    23/02/2022
# 13101    22/02/2022
# 13110    21/02/2022
# 13120    21/02/2022
# 13122    21/02/2022
# Name: receiving_date, Length: 494, dtype: object

# %%
df['receiving_date'][df['item_name']=='MOBILE']
# Out:
# 24       19/03/2024
# 26       18/03/2024
# 69       15/03/2024
# 134      10/03/2024
# 182      06/03/2024
#             ...
# 12950    01/03/2022
# 13038    25/02/2022
# 13146    14/02/2022
# 13320    07/02/2022
# 13422    01/02/2022
# Name: receiving_date, Length: 238, dtype: object

# %%
df['item_name'][df['item_quantity']=='2']
# Out:
# 4                                                   JACKET
# 5                                                      BAG
# 59                                         HAMMER & BOTTLE
# 84                                               BLACK BAG
# 104                                      UMBRELLA & BOTTLE
#                                ...
# 9679                                              ORNAMENT
# 10755                 ONE CARRY BAG HAVING CLOTHE AND BOOK
# 10756    ONE BAG HAVING EARPHONE AND MEDICAL CERTIFICAT...
# 12656            BAG WITH GLOVES, , EARPHONE ,SCREW PACKET
# 12781                                          DOOR HANDLE
# Name: item_name, Length: 69, dtype: object

# %%
import plotly.express as px # for  data visualization i.e provides functions to visualize a variety of types of dataimport matplotlib.pyplot as plt # to plot  diffrent charts
import matplotlib.pyplot as plt # to plot  diffrent charts

# %%
station_counts = df['station_name'].value_counts()

# Now you can plot station_counts
plt.figure(figsize=(10, 6))
station_counts.plot(kind='bar')
plt.title('Number of Items Received per Station')
plt.xlabel('Station Name')
plt.ylabel('Number of Items Received')
plt.show()

# %%
plt.figure(figsize=(10, 6))
station_counts.plot(kind='bar', color='skyblue')
plt.title('Total Quantity of Items Received per Station')
plt.xlabel('Station Name')
plt.ylabel('Total Quantity of Items Received')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
plt.subplot(2, 1, 2)
plt.pie(station_counts, labels=station_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of Items Received by Station')
plt.tight_layout()

# %%
# Pie chart
plt.subplot(2, 1, 2)
plt.pie(station_counts, labels=station_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of Items Received by Station')
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(station_counts, labels=station_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Total Quantity of Items Received per Station')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.0999999990206926,
#  1.0999999999533663,
#  -1.0999999999980246,
#  1.099999999999906)
